# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# plt.plot
# plt.scatter

# %%
array_x = np.array([1,3,5,9])
array_y = np.array([10,-5,3,6])
plt.plot(array_x,array_y)
plt.scatter(array_x,array_y)

# %%
df = pd.read_csv('advertising.csv')
print(data)
df.plot(x='TV',y='Sales',kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 df = pd.read_csv('advertising.csv')
# ----> 2 print(data)
#       3 df.plot(x='TV',y='Sales',kind='scatter')
#
# NameError: name 'data' is not defined

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data_tv = df['TV']
print(data_tv)
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 195     38.2
# 196     94.2
# 197    177.0
# 198    283.6
# 199    232.1
# Name: TV, Length: 200, dtype: float64

# %%
data_tv = data_tv.to_numpy()
print(data_tv.shape)
# Out:
# (200,)

# %%
data_sales = df['Sales'].to_numpy()

# %%
plt.scatter(data_tv,data_sales)

# %%
data_tv_25 = data_tv[data_tv<=74.3]
print(data_tv_25.shape)
# Out:
# (50,)

# %%
plt.hist(data_tv,bins=10)
plt.plot()
# Out:
# []

# %%
df['TV'].plot.hist(bins=40)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.boxplot(data_tv)
plt.plot()
# Out:
# []

# %%
df.boxplot(column=['TV'])
# Out:
# <Axes: >

# %%
sns.jointplot(x='TV',y='Sales',data=df)
